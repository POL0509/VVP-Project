# %%
from Fractals.fractals import Fractals
import importlib
importlib.reload(fractals)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/polyy/Fractals/example.ipynb Cell 1 in 3
#       <a href='vscode-notebook-cell:/home/polyy/Fractals/example.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> from Fractals.fractals import Fractals
#       <a href='vscode-notebook-cell:/home/polyy/Fractals/example.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import importlib
# ----> <a href='vscode-notebook-cell:/home/polyy/Fractals/example.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> importlib.reload(fractals)
#
# NameError: name 'fractals' is not defined

# %%
# %matplotlib ipympl
from matplotlib import pyplot as plt
from matplotlib.widgets import Slider
import numpy as np

# %%
c = -0.4+0.6j
fractal = Fractals(-2.5, 1, -1.5, 1.5, c, 250, 100, 10, 10, 'mandelbrot', 'jet', None)
fractal.show()
#slider_iter.on_changed(fractal.update_iter)

#def reset(event):
 #   slider_iter.reset()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
