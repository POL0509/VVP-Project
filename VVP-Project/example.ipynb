# %%
from Fractal import fractals
import importlib
importlib.reload(fractals)
# Out:
# <module 'Fractal.fractals' from '/home/polyy/Fractals/VVP-Project/Fractal/fractals.py'>

# %%
from Fractal.fractals import Fractals
from matplotlib import pyplot as plt
from matplotlib.widgets import Slider
import numpy as np

# %%
# %matplotlib ipympl

c = -0.4+0.6j
fractal = Fractals(-2.5, 1.5, -1.5, 1.5, c, 250, 100, 10, 10, 'mandelbrot', 'jet', None)
fractal.show()
# Out:
# /home/polyy/Fractals/VVP-Project/Fractal/fractals.py:75: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "generate_fractal" failed type inference due to: non-precise type pyobject
# During: typing of argument at /home/polyy/Fractals/VVP-Project/Fractal/fractals.py (83)
#
# File "Fractal/fractals.py", line 83:
#     def generate_fractal(self):
#         <source elided>
#         zoom = self._zoom ** 10
#         x = np.linspace(self._x_min/zoom, self._x_max/zoom, self._n)
#         ^
#
#   int: Number of iterations needed
# /home/polyy/Fractals/VVP-Project/Fractal/fractals.py:75: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "generate_fractal" failed type inference due to: Cannot determine Numba type of <class 'numba.core.dispatcher.LiftedLoop'>
#
# File "Fractal/fractals.py", line 87:
#     def generate_fractal(self):
#         <source elided>
# ...
